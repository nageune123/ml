# %%
import pandas as pd
test=pd.read_csv("./data2/test.csv",index_col="no")
train=pd.read_csv("./data2/train.csv",index_col="no")

# %%
train.shape,test.shape
# Out:
# ((20425, 51), (4396, 51))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,5))
sns.countplot(data = train,
             x='age',
             hue='income')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
train.drop(['capital-loss'],axis=1, inplace=True)
test.drop(['capital-loss',],axis=1, inplace=True)

# %%
train.drop(['capital-gain'],axis=1, inplace=True)
test.drop(['capital-gain'],axis=1, inplace=True)

# %%
train['fnlwgt']
# Out:
# no
# 1        219199
# 2         52978
# 3        196899
# 4        135527
# 5         60783
#           ...
# 29301    100605
# 29302    372636
# 29303    258474
# 29304    157446
# 29305     94809
# Name: fnlwgt, Length: 29305, dtype: int64

# %%
train['marital-status'].value_counts()

# %%
plt.figure(figsize=(24,5))
sns.countplot(data = train,
             x='fnlwgt',
             hue='income')
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='count'>

# %%
train['race'].value_counts()
# Out:
#  White                 25081
#  Black                  2776
#  Asian-Pac-Islander      919
#  Amer-Indian-Eskimo      290
#  Other                   239
# Name: race, dtype: int64

# %%
train
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# no
# 1       25            Private  219199           11th              7
# 2       39            Private   52978   Some-college             10
# 3       35            Private  196899      Bachelors             13
# 4       64            Private  135527      Assoc-voc             11
# 5       24            Private   60783   Some-college             10
# ...    ...                ...     ...            ...            ...
# 29301   20            Private  100605        HS-grad              9
# 29302   21            Private  372636        HS-grad              9
# 29303   18   Self-emp-not-inc  258474           10th              6
# 29304   33            Private  157446           11th              7
# 29305   65                  ?   94809        HS-grad              9
#
#             marital-status          occupation    relationship  \
# no
# 1                 Divorced   Machine-op-inspct   Not-in-family
# ...

# %%
bins = [0,39,70,99]  # 구간
labels = ['0~39','40~70','70~99'] # 구간 별 범주 이름
train['hours-per-week-Group']=pd.cut(x=train['hours-per-week'],
      bins=bins,
      labels=labels)

# %%
bins = [0,39,70,99]  # 구간
labels = ['0~39','40~70','70~99'] # 구간 별 범주 이름
test['hours-per-week-Group']=pd.cut(x=train['hours-per-week'],
      bins=bins,
      labels=labels)

# %%
train

# %%
train
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# no
# 1       25            Private  219199           11th              7
# 2       39            Private   52978   Some-college             10
# 3       35            Private  196899      Bachelors             13
# 4       64            Private  135527      Assoc-voc             11
# 5       24            Private   60783   Some-college             10
# ...    ...                ...     ...            ...            ...
# 29301   20            Private  100605        HS-grad              9
# 29302   21            Private  372636        HS-grad              9
# 29303   18   Self-emp-not-inc  258474           10th              6
# 29304   33            Private  157446           11th              7
# 29305   65                  ?   94809        HS-grad              9
#
#             marital-status          occupation    relationship  \
# no
# 1                 Divorced   Machine-op-inspct   Not-in-family
# ...

# %%
train['relationship'].unique()

# %%
train.drop(['capital-gain'],axis=1, inplace=True)
test.drop(['capital-gain'],axis=1, inplace=True)

# %%
train.drop(['education'],axis=1, inplace=True)
test.drop(['education'],axis=1, inplace=True)

# %%
bins = [0,39,70,99]  # 구간
labels = ['0~39','40~70','70~99'] # 구간 별 범주 이름
test['hours-per-week-Group']=pd.cut(x=train['hours-per-week'],
      bins=bins,
      labels=labels)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hours-per-week'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
sns.violinplot( data=train,
               x='sex',
              y='fnlwgt',hue='income',
              split=True)

# %%
plt.figure(figsize=(40,5))
sns.countplot(data = train,
             x='capital-loss',
             hue='income')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17816\529805798.py in <module>
#       1 plt.figure(figsize=(40,5))
# ----> 2 sns.countplot(data = train,
#       3              x='capital-loss',
#       4              hue='income')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
# ...

# %%
train['occupation'].unique()

# %%
plt.figure(figsize=(20,5))
sns.countplot(data = train,
             x='fnlwgt',
             hue='income')

# %%
train[].sum()

# %%
train.describe()

# %%
plt.figure(figsize=(20,5))
sns.countplot(data = train,
             x='education',
             hue='income')

# %%
plt.figure(figsize=(20,5))
sns.countplot(data = train,
             x='education-num',
             hue='income')

# %%
sns.violinplot('race','age',hue='income',data=train,split=True)

# %%
sns.violinplot('education-num','age',hue='income',data=train,split=True)

# %%
train.count()

# %%
train.corr()

# %%
train_1=train.drop('education',axis=1)
train_1
y_test_1=test.drop('education',axis=1)
y_test_1

# %%
train['hours-per-week'].unique()
sns.countplot(data = train,
             x='hours-per-week',
             hue='income')

# %%
plt.figure(figsize=(22,5))
sns.countplot(data = train,
             x='occupation',
             hue='income')

# %%
train.drop(['education'],axis=1, inplace=True)

# %%
plt.figure(figsize=(20,5))
sns.countplot(data = train,
             x='marital-status',
             hue='income')

# %%
train['education-num'].unique()

# %%
df.loc[(df['class']=='GALAXY'), 'class']=0

# %%
train['workclass'].count

# %%
train.loc(train['workclass']==' ?'),'workclass'=

# %%
sns.violinplot('age','hours-per-week',hue='income',data=train,split=True)

# %%
train['workclass'].unique()

# %%
train['marital-status'].unique()

# %%
train['workclass'].unique()

# %%
plt.figure(figsize=(20,5))
sns.countplot(data = train,
             x='education-num',
             hue='income')

# %%
train[train['workclass']==' ?']

# %%
train['native-country'].unique()

# %%
plt.figure(figsize=(22,5))
sns.countplot(data = train,
             y='native-country',
             hue='income')

# %%
train['native-country'].unique()

# %%
plt.figure(figsize=(24,5))
sns.countplot(data = test,
             x='workclass')

# %%
train['workclass'].value_counts()

# %%
sns.violinplot( data=train,
              y='fnlwgt',x='relationship',hue='income',
              split=True)

# %%
test
# Out:
#        age  fnlwgt  education-num  workclass_ ?  workclass_ Federal-gov  \
# no
# 29306   18  245274             10             1                       0
# 29307   29   83003              9             0                       0
# 29308   45   35136             13             0                       0
# 29309   42   64631             13             0                       0
# 29310   41  195821             16             0                       0
# ...    ...     ...            ...           ...                     ...
# 48838   45  116789              9             0                       0
# 48839   48  185079              9             0                       0
# 48840   63  117473             10             0                       0
# 48841   18  150817              7             0                       0
# 48842   31  341632             12             0                       0
#
#        workclass_ Local-gov  workclass_ Never-worked  workclass_ Private  \
# no
# ...

# %%
categorical_features=['workclass', 'marital-status', 'occupation', 'relationship','race','sex','hours-per-week-Group']

# %%
for feature_name in categorical_features:
    one_hot=pd.get_dummies(test[feature_name],prefix=feature_name) # 원핫 인코딩
    test.drop(feature_name, axis=1, inplace=True) # 기존 글자형태 컬럼 삭제
    test = pd.concat([test,one_hot],axis=1)

# %%
for feature_name in categorical_features:
    one_hot=pd.get_dummies(train[feature_name],prefix=feature_name) # 원핫 인코딩
    train.drop(feature_name, axis=1, inplace=True) # 기존 글자형태 컬럼 삭제
    train = pd.concat([train,one_hot],axis=1)

# %%
train.drop(['native-country'],axis=1, inplace=True)
test.drop(['native-country',],axis=1, inplace=True)

# %%
train
# Out:
#        age  fnlwgt  education-num  income  workclass_ ?  \
# no
# 1       25  219199              7       0             0
# 2       39   52978             10       0             0
# 3       35  196899             13       0             0
# 4       64  135527             11       0             0
# 5       24   60783             10       1             0
# ...    ...     ...            ...     ...           ...
# 29301   20  100605              9       0             0
# 29302   21  372636              9       0             0
# 29303   18  258474              6       0             0
# 29304   33  157446              7       0             0
# 29305   65   94809              9       0             1
#
#        workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  \
# no
# 1                           0                     0                        0
# 2                           0                     0                        0
# ...

# %%
set(train.columns)-set(test.columns)
# Out:
# {'income'}

# %%
X_train=train.drop('income',axis=1)
y_train=train['income']

# %%
X_test=test

# %%
X_test=X_test[X_train.columns]

# %%
X_train.to_csv('X_train.csv',index=False)
y_train.to_csv('y_train.csv',index=False)
X_test.to_csv('X_test.csv',index=False)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
knn_model = KNeighborsClassifier() # 거리
tree_model = DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train,y_val=train_test_split(X_train,y_train)

# %%
X_train.shape,y_train.shape
# Out:
# ((21978, 50), (21978,))

# %%
X_val.shape,y_val.shape
# Out:
# ((7327, 50), (7327,))

# %%
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(knn_model.score(X_val,y_val)) # score 정확도
print(tree_model.score(X_val,y_val))
# Out:
# 0.7221236522451208
# 0.780537737136618
# C:\Users\smhrd\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
knn_result=cross_val_score(knn_model,X_train,y_train,cv=5)

# %%
knn_result.mean()
# Out:
# 0.7193104704763147

# %%
# cross_val_score( 모델, 문제 데이터, 정답데이터, 몇 겹(k))
tree_result=cross_val_score(tree_model,X_train,y_train,cv=5)
print(tree_result)
# Out:
# [0.78252957 0.77797998 0.77616015 0.78134243 0.77974972]

# %%
tree_result.mean()
# Out:
# 0.7795523699795346

# %%
X_train.shape,y_train.shape
# Out:
# ((21978, 50), (21978,))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
transform_X_train=scaler.transform(X_train)

# %%
transform_X_test=scaler.transform(X_test)

# %%
result=cross_val_score(knn_model,transform_X_train,y_train)
print(result)
result.mean()
# Out:
# [0.80959964 0.81437671 0.81346679 0.82275313 0.8188851 ]
# 0.8158162710748524

# %%
score_list=[]
for k in range(1,150,2): # 이웃이 작으면 복잡, 많으면 단순
    knn_model=KNeighborsClassifier(n_neighbors=k) # 이웃에 따른 모델 생성
    knn_result=cross_val_score(knn_model,transform_X_train,y_train,cv=5) # 교차검증 성능
    score_list.append(knn_result.mean()) # 평균치 리스트에 담기

# %%
plt.figure(figsize=(45,5))
plt.plot(range(1,150,2), score_list)
plt.xticks(range(1,150,2))
plt.grid()
plt.show()

# %%
max(score_list)
# Out:
# 0.8275551877236623

# %%
from lightgbm import LGBMClassifier
from lightgbm import early_stopping
from lightgbm import log_evaluation

# %%
score_lst = []
for i in range(400,2000,100):
    lgbm_model = LGBMClassifier(n_estimators=i)
    score = cross_val_score(lgbm_model,X_train, y_train, cv =5)
    score_lst.append(score.mean())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17816\922251536.py in <module>
#       2 for i in range(400,2000,100):
#       3     lgbm_model = LGBMClassifier(n_estimators=i)
# ----> 4     score = cross_val_score(lgbm_model,X_train, y_train, cv =5)
#       5     score_lst.append(score.mean())
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# ...

# %%
a = 0
for i in score_list:
    a+=1
    if i==max(score_list):
        print(a)
# Out:
# 18

# %%
knn_model=KNeighborsClassifier(n_neighbors=18)# 이웃에 따른 모델 생성
knn_result=cross_val_score(knn_model,transform_X_train,y_train,cv=5) # 교차검증 성능
knn_result.mean()
# Out:
# 0.8252347309219985

# %%
knn_model = KNeighborsClassifier(n_neighbors=18)
knn_model.fit(X_train, y_train)
pre = knn_model.predict(X_test)

# %%
 sub = pd.read_csv('data2/sample_submission.csv')
 sub['income'] = pre
 sub.to_csv('practice.csv',index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
forest = RandomForestClassifier(n_estimators=90,max_features=0.3,max_depth=5)

# %%
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=0.3, n_estimators=90)

# %%
X_train.shape,y_train.shape
# Out:
# ((15384, 50), (15384,))

# %%
X_test.shape
# Out:
# (6594, 50)

# %%
pre.size
# Out:
# 19537

# %%
sub
# Out:
#           no  income
# 0      29306       0
# 1      29307       0
# 2      29308       1
# 3      29309       0
# 4      29310       1
# ...      ...     ...
# 19532  48838       0
# 19533  48839       0
# 19534  48840       0
# 19535  48841       0
# 19536  48842       0
#
# [19537 rows x 2 columns]

# %%
# 학습한 모델로 예측
pre = forest.predict(X_test)
# 평가 결과 서식 불러오기
sub = pd.read_csv('data2/sample_submission.csv')
sub['income'] = pre
sub.to_csv('practice2.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17816\2634841381.py in <module>
#       1 # 학습한 모델로 예측
# ----> 2 pre = forest.predict(X_test)
#       3 # 평가 결과 서식 불러오기
#       4 sub = pd.read_csv('data2/sample_submission.csv')
#       5 sub['income'] = pre
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     806             The predicted classes.
#     807         """
# --> 808         proba = self.predict_proba(X)
#     809
#     810         if self.n_outputs_ == 1:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     846             classes corresponds to that in the attribute :term:`classes_`.
#     847         """
# --> 848         check_is_fitted(self)
#     849         # Check data
#     850         X = self._validate_X_predict(X)
#
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adaboost = AdaBoostClassifier(n_estimators=500)

# %%
adaboost.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=500)

# %%
pre = adaboost.predict(X_test)

# %%
sub = pd.read_csv('data2/sample_submission.csv')
sub['income'] = pre
sub.to_csv('practice3.csv',index=False)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbm = GradientBoostingClassifier(n_estimators=500,learning_rate=0.1,max_depth=5)

# %%
gbm.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=5, n_estimators=500)

# %%
pre = gbm.predict(X_test)
pre
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV
param_knn = {"n_neighbors":range(1,10,1)}
# GridSearchCV(모델, 하이퍼파라미터 및 범위, 교차검증 수)
grid_search_Gradient = GridSearchCV(GradientBoostingClassifier(),param_knn,cv=10)

# %%
param_knn ={"max_depth":range(1,5,1),
            "max_leaf_nodes":range(1,50,10),
            "min_samples_leaf":range(1,150,10)}
grid_search_Gradient = GridSearchCV(GradientBoostingClassifier(),param_knn,cv=10)
grid_search_Gradient
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingClassifier(),
#              param_grid={'max_depth': range(1, 5),
#                          'max_leaf_nodes': range(1, 50, 10),
#                          'min_samples_leaf': range(1, 150, 10)})

# %%
grid_search_Gradient.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingClassifier(),
#              param_grid={'max_depth': range(1, 5),
#                          'max_leaf_nodes': range(1, 50, 10),
#                          'min_samples_leaf': range(1, 150, 10)})

# %%
print("최적의 하이퍼 파라미터 : ", grid_search_Gradient.best_params_)
print("최고 교차 검증 점수(정확도) : ",grid_search_Gradient.best_score_)
# 최고 성능 모델은 grid_search_knn 객체에 저장되어 있기 때문에 쓰지 않아도 됨
print("최고 성능 모델 : ",grid_search_Gradient.best_estimator_)
# Out:
# 최적의 하이퍼 파라미터 :  {'max_depth': 4, 'max_leaf_nodes': 11, 'min_samples_leaf': 91}
# 최고 교차 검증 점수(정확도) :  0.8408077881454105
# 최고 성능 모델 :  GradientBoostingClassifier(max_depth=4, max_leaf_nodes=11, min_samples_leaf=91)

# %%
sub = pd.read_csv('data2/sample_submission.csv')
sub['income'] = pre
sub.to_csv('practice4.csv',index=False)

# %%
import xgboost as xgb

# %%
from xgboost.sklearn import XGBClassifier

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
xgb = XGBClassifier(n_estimator=400, learning_rate=0.1,max_depth=3)

# %%
xgb.fit(X_train, y_train)
# Out:
# [16:44:46] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimator" } are not used.
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimator=400, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, ...)

# %%
pre = xgb.predict(X_test)
pre
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
sub = pd.read_csv('data2/sample_submission.csv')
sub['income'] = pre
sub.to_csv('practice5.csv',index=False)

# %%
from lightgbm import LGBMClassifier

lgb_cancer =LGBMClassifier(n_estimators=400)

# %%
from lightgbm import log_evaluation
from lightgbm import early_stopping

# %%
lgb =LGBMClassifier(n_estimators=400)
# 콜백함수 : 다른 함수의 인자로써 이용되는 함수
lgb.fit(X_train,y_train)
# Out:
# LGBMClassifier(n_estimators=400)

# %%
pre = lgb.predict(X_test)

# %%
sub = pd.read_csv('data2/sample_submission.csv')
sub['income'] = pre
sub.to_csv('practice6.csv',index=False)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier

decision = DecisionTreeClassifier()
param = {
    'max_depth':range(1, 21),
    'max_leaf_nodes':range(5, 101, 5),
}
n_iter = 80 # n_iter : 파라미터 검색 횟수

Randomized = RandomizedSearchCV(decision,
                        param_distributions=param, # 매개 변수
                        n_iter=n_iter, # 파라미터 검색 횟수
                        cv=5, # 교차검증 갯수
                        n_jobs=-1) # 사용할 CPU 코어 개수 (1: 기본값, -1: 모든 코어 다 사용)
Randomized.fit(X_train, y_train)
Randomized.cv_results_ # parameter 조합 별 결과 조화
Randomized.best_params_ # 가장 좋은 성능 parameter 조합
Randomized.best_estimator_ # 최고 성능 모델 반환
# Out:
# DecisionTreeClassifier(max_depth=9, max_leaf_nodes=70)

# %%
pre = Randomized.predict(X_test)

# %%
sub = pd.read_csv('data2/sample_submission.csv')
sub['income'] = pre
sub.to_csv('practice7.csv',index=False)

# %%
train
# Out:
#        age  fnlwgt  education-num  income  workclass_ ?  \
# no
# 1       25  219199              7       0             0
# 2       39   52978             10       0             0
# 3       35  196899             13       0             0
# 4       64  135527             11       0             0
# 5       24   60783             10       1             0
# ...    ...     ...            ...     ...           ...
# 29301   20  100605              9       0             0
# 29302   21  372636              9       0             0
# 29303   18  258474              6       0             0
# 29304   33  157446              7       0             0
# 29305   65   94809              9       0             1
#
#        workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  \
# no
# 1                           0                     0                        0
# 2                           0                     0                        0
# ...

# %%
train['capital-loss']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'capital-loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
X_test=X_test[X_train.columns]

# %%
from sklearn.model_selection import train_test_split

# Step1) train / test 으로 나누기
train, test = train_test_split(train, test_size=0.15, random_state=1)

# Step2) train을 다시 train/validation 으로 나누기
train, val = train_test_split(train, test_size = 0.18, random_state=1)


# 확인
train.shape, val.shape, test.shape
# Out:
# ((20425, 51), (4484, 51), (4396, 51))

# %%
X_train,X_test, y_train, y_test = train_test_split(X_train,
                                                  y_train,
                                                  test_size = 0.3,
                                                  random_state=3)

# %%
from sklearn.model_selection import GridSearchCV
param_knn = {"n_neighbors":range(1,10,1)}
# GridSearchCV(모델, 하이퍼파라미터 및 범위, 교차검증 수)
grid_search_knn = GridSearchCV(KNeighborsClassifier(),param_knn,cv=10)

# %%
grid_search_knn.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 10)})

# %%
print("최적의 하이퍼 파라미터 : ", grid_search_knn.best_params_)
print("최고 교차 검증 점수(정확도) : ",grid_search_knn.best_score_)
# 최고 성능 모델은 grid_search_knn 객체에 저장되어 있기 때문에 쓰지 않아도 됨
print("최고 성능 모델 : ",grid_search_knn.best_estimator_)
# Out:
# 최적의 하이퍼 파라미터 :  {'n_neighbors': 8}
# 최고 교차 검증 점수(정확도) :  0.7479197560437723
# 최고 성능 모델 :  KNeighborsClassifier(n_neighbors=8)
